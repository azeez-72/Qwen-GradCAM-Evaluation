# %% [markdown]
# # Baseline 3 Evaluation

# %% [markdown]
# ### Initial package installaions

# %%
# Install required packages
# !pip install -q transformers accelerate bitsandbytes pillow pandas torch opencv-python einops
# !pip install qwen-vl-utils

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 43.7 MB/s eta 0:00:00
# Collecting qwen-vl-utils
#   Downloading qwen_vl_utils-0.0.14-py3-none-any.whl.metadata (9.0 kB)
# Collecting av (from qwen-vl-utils)
#   Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qwen-vl-utils) (25.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from qwen-vl-utils) (11.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from qwen-vl-utils) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->qwen-vl-utils) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->qwen-vl-utils) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->qwen-vl-utils) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->qwen-vl-utils) (2025.11.12)
# Downloading qwen_vl_utils-0.0.14-py3-none-any.whl (8.1 kB)
# Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 64.8 MB/s eta 0:00:00
# Installing collected packages: av, qwen-vl-utils
# Successfully installed av-16.0.1 qwen-vl-utils-0.0.14
# Mounted at /content/drive

# %% [markdown]
# ### Setup and Configurations

# %%
import os
import random
import re
import torch
import numpy as np
import pandas as pd
from PIL import Image
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info
import torch.backends.cudnn as cudnn
import warnings

# Clean Environment
warnings.filterwarnings("ignore")
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['HUGGINGFACE_HUB_FORCE_REDOWNLOAD'] = '1'
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

def get_config(
    model_id="Qwen/Qwen2.5-VL-7B-Instruct",
    seed=520,
    image_root_dir="/content/drive/MyDrive/VLM/paper_figures/",
):
    """Returns a dictionary containing all configuration settings, excluding dynamic values."""
    device = "cuda" if torch.cuda.is_available() else "cpu"

    PANEL_PROMPT = """
    You are a visual-language expert specialized in analyzing multi-panel scientific figures. Each panel may be labeled with letters (A, B, C, D, etc.) or alphanumeric labels (e.g., 1A, A5, 3B, etc.).

    Task
    1. Examine the provided figure carefully and identify all visible panel labels (A, B, 1A, A5, etc.).
    2. Determine which specific labeled panel best supports the following scientific claim:

    Claim:
    "{claim}"

    Instructions
    1. Read and interpret each labeled panel visually – focus on trends, comparisons, correlations, or experimental results.
    2. Identify which panel (by its exact visible label) provides the strongest direct visual evidence supporting the claim.
    3. The label can be alphabetic or alphanumeric (e.g., A, B, 5A, A5, C2, etc.).
    4. If no panel clearly supports the claim, output Panel: None and briefly explain why.
    5. Provide a concise but clear explanation – up to 3 lines having max 20 words, focusing on visual reasoning only.

    Output Format (must follow exactly)
    - Line 1: Panel: <exact visible label or None>
    - Line 2: Reason: <first line of reasoning>
    - Line 3 (optional): <second line of reasoning>
    - Line 4 (optional): <third line of reasoning>

    Do NOT include any extra commentary, numbering, markdown, or quotes.

    Provide your answer in the exact format above.
    """

    VERIFICATION_PROMPT = """
    You are a visual-language expert specialized in analyzing multi-panel scientific figures.
    Each panel may be labeled with letters (A, B, C, D, etc.) or alphanumeric labels (e.g., 1A, A5, 3B, etc.).
    You will be given a specific ground truth sub-panel from a figure and a scientific claim.
    Your task is to determine if the visual evidence in that specific panel supports the claim.

    Input Data
    - Target Panel: "{panel_label}" (Look ONLY at this panel in the figure)
    - Claim: "{claim}"

    Instructions
    1. Locate the assigned 'Target Panel' in the image. Ignore all other panels.
    2. Analyze the data in that panel (visual trends, bar heights, scatter plots, or microscopy features, comparisons, correlations, or experimental results).
    3. Compare the visual data against the Claim.
    4. Determine the verdict:
      - SUPPORT: The visual trends/data directly match the claim (e.g., Claim says 'increase', Graph shows rising slope).
      - NON_SUPPORT: The visual data contradicts the claim (e.g., Claim says 'increase', Graph shows flat/drop) OR the panel does not contain relevant information.

    Output Format (Strict)
    - Verdict: <SUPPORT or NON_SUPPORT>
    - Reason: <One short sentence (max 20 words) describing the specific visual feature (slope, bar difference, spatial arrangement) that justifies your verdict.>

    Do NOT include any extra text, markdown, or intros.
    """

    return {
        "MODEL_ID": model_id,
        "SEED": seed,
        "DEVICE": device,
        "IMAGE_ROOT_DIR": image_root_dir,
        "PANEL_PROMPT": PANEL_PROMPT,
        "VERIFICATION_PROMPT": VERIFICATION_PROMPT,
    }

def set_seeds(seed):
    """Sets random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    cudnn.benchmark = False
    cudnn.deterministic = True

config = get_config()
set_seeds(config["SEED"])
print(f"✅ Configuration loaded. Running on {config['DEVICE']}")
# Out:
# ✅ Configuration loaded. Running on cuda

# %%
def setup_seeds():
    seed = 520

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    cudnn.benchmark = False
    cudnn.deterministic = True

setup_seeds()
device = torch.device("cuda") if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# device(type='cuda')

# %%
config['DEVICE']
# Out:
# 'cuda'

# %% [markdown]
# ### Initialize and Load the Qwen Model

# %%
def initialize_model_and_processor(model_id, device):
    """Loads the Qwen2.5-VL model and processor."""
    print(f"🧠 Loading model: {model_id}...")
    model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
        model_id,
        dtype=torch.float32,
        device_map="cuda"
    )
    for name, param in model.named_parameters():
        param.requires_grad_(True)

    processor = AutoProcessor.from_pretrained(model_id)
    print("✅ Model and processor loaded.")
    return model, processor

# %%
model, processor = initialize_model_and_processor(config["MODEL_ID"], config["DEVICE"])
# Out:
# 🧠 Loading model: Qwen/Qwen2.5-VL-7B-Instruct...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.09G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/216 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# ✅ Model and processor loaded.

# %%
model
# Out:
# Qwen2_5_VLForConditionalGeneration(
#   (model): Qwen2_5_VLModel(
#     (visual): Qwen2_5_VisionTransformerPretrainedModel(
#       (patch_embed): Qwen2_5_VisionPatchEmbed(
#         (proj): Conv3d(3, 1280, kernel_size=(2, 14, 14), stride=(2, 14, 14), bias=False)
#       )
#       (rotary_pos_emb): Qwen2_5_VisionRotaryEmbedding()
#       (blocks): ModuleList(
#         (0-31): 32 x Qwen2_5_VLVisionBlock(
#           (norm1): Qwen2RMSNorm((1280,), eps=1e-06)
#           (norm2): Qwen2RMSNorm((1280,), eps=1e-06)
#           (attn): Qwen2_5_VLVisionAttention(
#             (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (mlp): Qwen2_5_VLMLP(
#             (gate_proj): Linear(in_features=1280, out_features=3420, bias=True)
#             (up_proj): Linear(in_features=1280, out_features=3420, bias=True)
#             (down_proj): Linear(in_features=3420, out_features=1280, bias=True)
#             (act_fn): SiLUActivation()
#           )
#         )
#       )
#       (merger): Qwen2_5_VLPatchMerger(
#         (ln_q): Qwen2RMSNorm((1280,), eps=1e-06)
#         (mlp): Sequential(
#           (0): Linear(in_features=5120, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=3584, bias=True)
#         )
#       )
#     )
#     (language_model): Qwen2_5_VLTextModel(
#       (embed_tokens): Embedding(152064, 3584)
#       (layers): ModuleList(
#         (0-27): 28 x Qwen2_5_VLDecoderLayer(
#           (self_attn): Qwen2_5_VLAttention(
#             (q_proj): Linear(in_features=3584, out_features=3584, bias=True)
#             (k_proj): Linear(in_features=3584, out_features=512, bias=True)
#             (v_proj): Linear(in_features=3584, out_features=512, bias=True)
#             (o_proj): Linear(in_features=3584, out_features=3584, bias=False)
#             (rotary_emb): Qwen2_5_VLRotaryEmbedding()
#           )
#           (mlp): Qwen2MLP(
#             (gate_proj): Linear(in_features=3584, out_features=18944, bias=False)
#             (up_proj): Linear(in_features=3584, out_features=18944, bias=False)
#             (down_proj): Linear(in_features=18944, out_features=3584, bias=False)
#             (act_fn): SiLUActivation()
#           )
#           (input_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#           (post_attention_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#         )
#       )
#       (norm): Qwen2RMSNorm((3584,), eps=1e-06)
#       (rotary_emb): Qwen2_5_VLRotaryEmbedding()
#     )
#   )
#   (lm_head): Linear(in_features=3584, out_features=152064, bias=False)
# )

# %% [markdown]
# ### Load and Prepare the Dataset

# %%
import pandas as pd

# %%
from datasets import load_dataset
from huggingface_hub import hf_hub_download
from PIL import Image

def load_and_filter_data():
    """Loads the Dataset from Hugging Face and filters rows based on 'support' labels."""
    ds = load_dataset("StonyBrookNLP/MuSciClaims", split="test")
    df = ds.to_pandas()

    filtered_df = df[
        (df['label_3class'].astype(str).str.lower() == "support") &
        (df['label_2class'].astype(str).str.lower() == "support")
    ].copy()

    print(f"Loaded {len(df)} total rows. Filtered down to: {len(filtered_df)} rows")
    return filtered_df

data_df = load_and_filter_data()
# Out:
# README.md: 0.00B [00:00, ?B/s]
# test_set.jsonl: 0.00B [00:00, ?B/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Loaded 1515 total rows. Filtered down to: 505 rows

# %%
# Preprocessing the claim from the dataset to only keep the relevant information
import re
import spacy

# Load the spacy model
nlp = spacy.load("en_core_web_sm")

def denoise_claim(text: str) -> str:
    if not text: return ""

    # Only remove explicit Figure/Panel references and that also matches: "Figure 1A", "Fig. 2", "Panel B" (case insensitive)
    text = re.sub(r'\b(?:Figure|Fig\.?|Panel)\s*[0-9A-Za-z]+\b', '', text, flags=re.IGNORECASE)

    # Remove parenthesized explicit refs like "(see Fig 1)" or "(Panel A)"
    text = re.sub(r'\(\s*(?:see)?\s*(?:Figure|Fig\.?|Panel)\s*[0-9A-Za-z]+\s*\)', '', text, flags=re.IGNORECASE)

    # Remove fillers at the start
    text = re.sub(r'^(Further|Furthermore|Moreover|In addition|Finally|Thus),?\s*', '', text, flags=re.IGNORECASE)

    # Semantic filtering of th text
    doc = nlp(text)

    KEEP_POS = {"NOUN", "PROPN", "VERB", "ADJ", "ADV", "NUM", "ADP", "PART", "SYM"}

    REMOVE_WORDS = {"the", "a", "an", "this", "that", "these", "those", "is", "are", "was", "were", "be", "been"}

    cleaned_tokens = []
    for token in doc:
        if token.text.lower() in REMOVE_WORDS:
            continue

        # Keep punctuation that defines structure
        if token.text in [',', ':', ';', '.', '%', '<', '>', '=']:
            cleaned_tokens.append(token.text)
            continue

        if token.pos_ in KEEP_POS:
            prefix = " " if cleaned_tokens and cleaned_tokens[-1] not in ['<', '>', '=', '-'] else ""
            cleaned_tokens.append(prefix + token.text)

    result = "".join(cleaned_tokens).strip()

    result = re.sub(r'\s+', ' ', result)
    result = re.sub(r'\s+([,.:])', r'\1', result)

    return result.strip()

# Apply the above preprocessing logic to our dataset
data_df['claim_text'] = data_df['claim_text'].apply(denoise_claim)

# %%
data_df['associated_figure_panels']
# Out:
# 0         [Panel I]
# 3         [Panel A]
# 6         [Panel C]
# 9         [Panel I]
# 12        [Panel K]
#            ...
# 1500    [Figure 3D]
# 1503    [Figure 4A]
# 1506    [Figure 4C]
# 1509    [Figure 5A]
# 1512    [Figure 5D]
# Name: associated_figure_panels, Length: 505, dtype: object

# %% [markdown]
# ### Initializing GRAD-CAM for evaluation

# %%
import pandas as pd
import torch
import numpy as np
import cv2
import os
import re
from PIL import Image
from einops import rearrange
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
class GradCAM():
    def __init__(self, model, target_layer, input_token_len, output_ids):
        self.model = model
        self.target_layer = target_layer
        self.feature_maps = None
        self.gradients = None

        self.input_token_len = input_token_len
        self.output_ids = output_ids

        self.target_ids = self.output_ids[0][self.input_token_len:]
        target_layer.register_forward_hook(self.save_feature_maps)
        target_layer.register_full_backward_hook(self.save_gradients)

    def save_feature_maps(self, module, input, output):
        self.feature_maps = output

    def save_gradients(self, module, grad_input, grad_output):
        self.gradients = grad_output[0].detach()

    def generate_cam(self, image, inputs, image_len, text_len):
        self.model.eval()
        self.model.zero_grad()
        out = self.model(**inputs)

        logits_shape = out.logits.shape
        target_logits = torch.sum(
            out.logits[0, self.input_token_len:self.output_ids.shape[1], :][
                torch.arange(len(self.target_ids)), self.target_ids.int()
            ]
        )

        if self.feature_maps is not None:
            self.feature_maps.retain_grad()

        target_logits.retain_grad()
        target_logits.backward(retain_graph=True)

        print(f"Feature maps shape: {self.feature_maps.shape}")

        # Handle both [batch, num_tokens, channels] and [num_tokens, channels]
        if len(self.feature_maps.shape) == 3:
            actual_num_tokens = self.feature_maps.shape[1]
            has_batch = True
        else:
            actual_num_tokens = self.feature_maps.shape[0]
            has_batch = False

        # Compute square root to get spatial dimension
        h = int(np.sqrt(actual_num_tokens))
        w = h  # Assume square featur maps

        if h * w != actual_num_tokens:
            print(f"Warning: Feature map tokens ({actual_num_tokens}) don't form perfect square")
            # Adjust to closest rectangular shape
            w = actual_num_tokens // h

        print(f"Reshaping to spatial grid: {h}x{w} = {h*w} tokens")

        # Use computed dimensions for reshaping (handle with/without batch dimension)
        if has_batch:
            self.feature_maps = rearrange(
                self.feature_maps.detach(),
                'b (h w) c -> b c h w',
                h=h,
                w=w
            ).squeeze(0)

            self.gradients = rearrange(
                self.gradients.detach(),
                'b (h w) c -> b h w c',
                h=h,
                w=w
            ).squeeze(0)
        else:
            # No batch dimension - direct reshape
            self.feature_maps = rearrange(
                self.feature_maps.detach(),
                '(h w) c -> c h w',
                h=h,
                w=w
            )

            self.gradients = rearrange(
                self.gradients.detach(),
                '(h w) c -> h w c',
                h=h,
                w=w
            )

        self.gradients = nn.ReLU()(self.gradients)

        pooled_gradients = torch.mean(self.gradients, dim=[0, 1])

        # Weight feature maps by pooled gradients
        activation = self.feature_maps
        for i in range(activation.size(0)):
            activation[i, :, :] *= pooled_gradients[i]

        # Generate heatmap
        heatmap = torch.mean(activation.to(dtype=torch.float32), dim=0).squeeze().cpu().numpy()
        heatmap = np.maximum(heatmap, 0)

        if np.max(heatmap) > 0:
            heatmap /= np.max(heatmap)

        # Using percentile-based thresholding instead of fixed threshold
        threshold = np.percentile(heatmap[heatmap > 0], 50) if np.any(heatmap > 0) else 0.5
        print(f"Using adaptive threshold: {threshold:.3f}")
        heatmap[heatmap < threshold] = 0

        # Resize to original image dimensions
        heatmap = cv2.resize(heatmap, (image.size[0], image.size[1]))
        heatmap = np.uint8(255 * heatmap)
        heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

        # Create overlay
        original_image = np.array(image)
        superimposed_img = heatmap * 0.4 + original_image
        superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)

        return heatmap, superimposed_img

# %% [markdown]
# ### Generate GRAD-CAM

# %%
output_dir = "/content/drive/MyDrive/VLM/Baseline3/overlay"

# %%
import re
import os
import cv2
import torch
from PIL import Image

def predict_verification_with_gradcam(image_path, claim, ground_truth_panel, save_dir=None, perform_gradcam=True):

    image = Image.open(image_path).resize((384,384), resample=Image.Resampling.BOX)
    prompt_text = config['VERIFICATION_PROMPT'].format(claim=claim,panel_label=ground_truth_panel)

    messages = [{
        "role": "user",
        "content": [
            {"type": "image", "image": image},
            {"type": "text", "text": prompt_text}
        ]
    }]

    # Convert chat messages into a text prompt using the model's chat template
    text = processor.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )

    # Preprocess images/videos from the chat messages
    image_inputs, video_inputs = process_vision_info(messages)

    # Estimate image token length (Qwen-VL uses 28x28 = 784 pixel patches)
    image_len = image_inputs[0].size[0] * image_inputs[0].size[1] // (28 * 28)

    # Tokenize and prepare full multimodal input for the model
    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    )
    inputs = inputs.to("cuda")

    # Prepare text-only version to compute text token length (before image_pad tokens)
    ptext = processor(
        text=[text.split("<|image_pad|>")[0]],
        padding=True,
        return_tensors="pt",
    )
    text_len = ptext['input_ids'].shape[1]

    print(f"image_len: {image_len}, text_len: {text_len}")

    assert len(inputs.input_ids) == 1, inputs  # Ensure batch size = 1


    # Run autoregressive generation
    generated_ids = model.generate(**inputs, max_new_tokens=128)

    # Length of input tokens, used to trim outputs
    input_token_len = [len(in_ids) for in_ids in inputs.input_ids][0]

    # Remove input tokens from the generated sequence to isolate new output
    generated_ids_trimmed = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]

    # Decode model output into text
    output_text = processor.batch_decode(
        generated_ids_trimmed,
        skip_special_tokens=False,
        clean_up_tokenization_spaces=False
    )
    output_text=output_text[0]
    print(output_text)

    # We look for verdicts "SUPPORT" and "NON_SUPPORT"
    verdict_match = re.search(r"Verdict\s*[:\-]+\s*(SUPPORT|NON_SUPPORT)", output_text, re.IGNORECASE)
    reason_match = re.search(r"Reason\s*[:\-]+\s*(.+)", output_text, re.DOTALL)

    verdict = verdict_match.group(1).upper() if verdict_match else "UNKNOWN"
    reason = reason_match.group(1).strip() if reason_match else output_text.strip()

    inputs_out = processor(
        text=[text + output_text],   # using [text + output_text] to backprop
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    )
    inputs_out = inputs_out.to("cuda")

    torch.cuda.empty_cache()

    # Early exit if Grad-CAM is not requested
    if not perform_gradcam:
        return {"verdict": verdict, "reason": reason, "raw_output": output_text}

    try:
        target_layer = model.visual.blocks[-1].norm2

        gradcam = GradCAM(model, model.visual.blocks[-1].norm2, input_token_len, generated_ids)

        print("  🎨 Generating Grad-CAM...")

        # ⚡ CORRECT: result is already the superimposed image
        heatmap, superimposed_img = gradcam.generate_cam(image, inputs=inputs_out, image_len=image_len, text_len=text_len)

        # SUper impose on the image
        filename = os.path.basename(image_path)
        name_only = os.path.splitext(filename)[0]
        overlay_path = os.path.join(output_dir, f"{name_only}_overlay.jpg")

        superimposed_rgb = cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB)
        cv2.imwrite(overlay_path, superimposed_rgb)
        print(f"Saved: {overlay_path}")

        return {"verdict": verdict, "reason": reason, "raw_output": output_text}

    except Exception as e:
        print(f"  ⚠️ Grad-CAM failed: {e}")
        import traceback
        traceback.print_exc()
        return {"verdict": verdict, "reason": reason, "raw_output": output_text, "gradcam_failed": True}

print("✅ Verification function ready")
# Out:
# ✅ Verification function ready

# %%
# Calculating Accuracy of the model
results = []
base_image_dir = config['IMAGE_ROOT_DIR']  # Update this path
num_to_process = len(data_df)
processed_images=0
matches=0
for idx, (i, row) in enumerate(data_df.head(num_to_process).iterrows()):
    img_name = str(row["associated_figure_filepath"].split('/')[-1]).strip()
    claim = str(row["claim_text"]).strip()
    img_path = base_image_dir + img_name
    ass_panel = str(row.get("associated_figure_panels", "")).strip()
    ass_verdict = str(row["label_2class"]).strip()

    print(f"\n{'='*60}")
    print(f"🔍 [{idx+1}/{num_to_process}] {img_name}")
    print(f"📋 Claim: {claim[:80]}...")
    print(f"🎯 Ground Truth: {ass_panel}")
    print(f"🎯 Associated verdict: {ass_verdict}")

    if not os.path.exists(img_path):
        print(f"\n⚠️ Skipping [{idx+1}]: Image not found at {img_path}")
        continue

    processed_images+=1
    out = predict_verification_with_gradcam(img_path, claim,ass_panel, perform_gradcam=False)

    print(f"✅ Predicted: {out['verdict']}")
    if out['verdict'] == ass_verdict:
        matches += 1

accuracy = matches/processed_images
accuracy = accuracy*100
print(f"Accuracy: {accuracy}%")
# Out:
# ============================================================
# 🔍 [1/505] bio_PIIS0092867425000455_images_figure_1.jpg
# 📋 Claim: introduction of stop codon in SunTag frame, insertion of one additional nucleoti...
# 🎯 Ground Truth: ['Panel I']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar graph shows significantly lower GFP foci for stop codon compared to sense codon.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [2/505] bio_PIIS0092867425000455_images_figure_2.jpg
# 📋 Claim: Interestingly, measuring GFP foci intensity over time for socRNAs translated by ...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The varying slopes of the curves indicate different elongation speeds among ribosomes.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [3/505] bio_PIIS0092867425000455_images_figure_2.jpg
# 📋 Claim: plateau traces show heterogeneity in slopes as well, heterogeneity substantially...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Plateau traces exhibit less heterogeneity in slopes compared to increasing traces, supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [4/505] bio_PIIS0092867425000455_images_figure_4.jpg
# 📋 Claim: In scenario, trailing ribosome not impeded by RNA structure structure unfolded b...
# 🎯 Ground Truth: ['Panel I']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The trailing ribosome pauses together with the leading ribosome, indicating no impeding effect on RNA structure unfolding.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [5/505] bio_PIIS0092867425000455_images_figure_4.jpg
# 📋 Claim: Comparing experiments with simulations revealed experimental run off values clos...
# 🎯 Ground Truth: ['Panel K']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Experimental and simulated curves align closely, showing cooperative behavior.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [6/505] bio_PIIS0092867425000455_images_figure_5.jpg
# 📋 Claim: To experimentally validate ribosome collisions underlie ribosome cooperativity, ...
# 🎯 Ground Truth: ['Panel C' 'Panel D']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Panel C shows two Xbp1(S255A) pause sites per socRNA, supporting the claim of designed socRNAs.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [7/505] bio_PIIS0092867425000455_images_figure_7.jpg
# 📋 Claim: However, rather than increase, observed stark reduction in pause frequency on so...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: The bar graph shows a higher probability for 1 ribosome compared to 2 ribosomes, contradicting the claim of a reduction in pause frequency.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [8/505] bio_PIIS0092867425000868_images_figure_1.jpg
# 📋 Claim: Striga germination rates also significantly increased about 9.88 - fold under Pi...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The bar height for -Pi treatment is significantly higher than CK, indicating an increase in germination rate.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [9/505] bio_PIIS0092867425000868_images_figure_3.jpg
# 📋 Claim: Additionally, further confirmed SbSLT1 LIKE SbSLT2 LIKE functional in oocytes, r...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: SbSLT1-LIKE and SbSLT2-LIKE bars are higher than GFP, indicating transport activity.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [10/505] bio_PIIS0092867425000868_images_figure_3.jpg
# 📋 Claim: Substituting isoleucine with phenylalanine in SbSLT1 LIKE SbSLT2 LIKE conferred ...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Decreased GR245DS content bars in SbSLT1-LIKE and SbSLT2-LIKE variants confirm efflux activity.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [11/505] bio_PIIS0092867425000868_images_figure_4.jpg
# 📋 Claim: 5DS levels in roots of SbSLT1ko SbSLT2ko mutants similar with in WT, SbSLT1koSbS...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar heights for SbSLT1ko SbSLT2ko double mutant are higher compared to WT, supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [12/505] bio_PIIS0092867425000868_images_figure_4.jpg
# 📋 Claim: mutants showed significantly reduced 5DS in exudates in hydroponic medium compar...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar heights show significant reduction in 5DS content for mutants compared to WT, with double mutant having lowest values.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [13/505] bio_PIIS0092867425000868_images_figure_3.jpg
# 📋 Claim: In yeast heterologous expression assays, SbSLT1F693A SbSLT2F642A variants signif...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: GR245DS content bars for SbSLT1F693A and SbSLT2F642A are lower than EV, supporting reduced export activity.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [14/505] bio_PIIS0092867425000868_images_figure_5.jpg
# 📋 Claim: double mutants had higher tiller numbers in later developmental stages, also con...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: The panel shows no direct evidence of increased tiller numbers in double mutants compared to single mutants.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [15/505] bio_PIIS0092867425000959_images_figure_1.jpg
# 📋 Claim: rate of m6A DMs within coding sequences CDSs consistent with background distribu...
# 🎯 Ground Truth: ['Panel D']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The histogram shows a skewed distribution towards lower m6A-DM counts per MB, consistent with a background mutation rate.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [16/505] bio_PIIS0092867425000959_images_figure_2.jpg
# 📋 Claim: more, observed marked differences between top ranked genes in terms of observed ...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a clear distinction in rank between mm6A-DM and sm6A-DM genes, supporting the claim of marked differences.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [17/505] bio_PIIS0092867425000959_images_figure_3.jpg
# 📋 Claim: For instance, E2F targets DNA repair pathways enriched in prostate carcinoma lar...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: E2F targets and Mitotic Spindle pathways are uniquely enriched in lung carcinoma, as indicated by the red bars in the panel.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [18/505] bio_PIIS0092867425001035_images_figure_4.jpg
# 📋 Claim: found pre - induction of associated ncRNA prior to AbiF expression completely ab...
# 🎯 Ground Truth: ['Panel D']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Microscopy images show more colonies in pre-induction of ncRNA group, indicating reduced toxicity.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [19/505] bio_PIIS0092867425001035_images_figure_4.jpg
# 📋 Claim: Expression of HEPN - inactive variant R210A+H215A rescued growth inhibition phen...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows that the HEPN inactive variant R210A+H215A with ncRNA expression rescues the growth inhibition phenotype compared to the dead HEPN variant.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [20/505] bio_PIIS0092867425001035_images_figure_5.jpg
# 📋 Claim: observed PbAbiF activity inhibited by PcAbiF BbAbiFr ncRNAs, suggesting robust A...
# 🎯 Ground Truth: ['Panel J']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar heights decrease as AbiF concentration increases, indicating inhibition of PbAbiF activity.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [21/505] bio_PIIS0092867425001096_images_figure_4.jpg
# 📋 Claim: Widefield fluorescence imaging demonstrated signal accumulating around periphery...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Fluorescence signal accumulates around cell periphery, matching DL data.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [22/505] bio_PIIS0092867425001096_images_figure_5.jpg
# 📋 Claim: Examination of cells stained with isotype antibodies reveals weaker signal csRBP...
# 🎯 Ground Truth: ['Panel D' 'Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Isotype staining shows weaker signal compared to csRBP β2M, with no similar colocalization patterns observed.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [23/505] bio_PIIS0092867425001096_images_figure_6.jpg
# 📋 Claim: Colocalization analysis demonstrated many csRNA puncta lie within optical diffra...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows overlapping distributions near the median distances, indicating close proximity of csRNA puncta to csRBPs.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [24/505] bio_PIIS0092867424014788_images_figure_3.jpg
# 📋 Claim: In cases, even close homologs with>80% sequence identity compared with tested ca...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Some candidates with high sequence identity show low AlphaFold2-Multimer model confidence scores, indicating poor binding predictions.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [25/505] bio_PIIS0092867425000352_images_figure_3.jpg
# 📋 Claim: In contrast to dual binding modes in GPR133 GAIN, 5a DHT found to adopt only hor...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: 5α-DHT adopts a horizontal binding position in GPR133-βT, as shown by the alignment of the ligand with the receptor's surface.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [26/505] bio_PIIS0092867425000352_images_figure_4.jpg
# 📋 Claim: Notably, four ring plane of 5a DHTH perpendicular to plasma membrane, of METH al...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: 5α-DHTH rings are shown perpendicular, while METH rings are depicted almost parallel to the membrane.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [27/505] bio_PIIS0092867425000352_images_figure_4.jpg
# 📋 Claim: Additionally, steroid ring stabilized by series of hydrophobic p p interactions....
# 🎯 Ground Truth: ['Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Steroid ring stabilized by hydrophobic interactions is visually supported by the spatial arrangement of hydrophobic residues around the steroid structure.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [28/505] bio_PIIS0092867425000364_images_figure_3.jpg
# 📋 Claim: However, lower proportion of speciesspecific interactions in human chimpanzee ov...
# 🎯 Ground Truth: ['Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Human-specific interactions have shorter bars than conserved interactions, indicating fewer overlaps.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [29/505] bio_PIIS0092867425000376_images_figure_1.jpg
# 📋 Claim: Indeed, in trials males near female<5 mm immediately prior to copulation, winged...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Winged males near females within 5 mm show lower success rates compared to wingless males, supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [30/505] bio_PIIS0092867425000376_images_figure_1.jpg
# 📋 Claim: However, competing males varied in speed, fidelity of courtship pursuit, frequen...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Scatter plots show no significant differences in speed, fidelity, or attempts between winners and losers.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [31/505] bio_PIIS0092867425000376_images_figure_2.jpg
# 📋 Claim: Bilateral wing flicks unilateral wing extensions thus comprise distinct channels...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Wing flicks are shown as distinct, continuous patterns, supporting the claim of bilateral wing flicks comprising distinct channels for acoustic communication.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [32/505] bio_PIIS0092867425000376_images_figure_5.jpg
# 📋 Claim: However, introducing even small temporal offsets between songs suppressed vpoEN ...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a decrease in vpoEN activity as offset increases, supporting narrow tuning.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [33/505] bio_PIIS0092867425000376_images_figure_5.jpg
# 📋 Claim: females took longer to copulate with mute male complex acoustic environment reco...
# 🎯 Ground Truth: ['Panel M']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Cumulative copulation rate curve for MF is higher than MMF, indicating faster copulation with simpler soundscapes.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [34/505] bio_PIIS0092867425000376_images_figure_1.jpg
# 📋 Claim: Agonistic wing flicks therefore appear to effectively jam female 's auditory pat...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: The graph shows no significant change in probability over time, contradicting the claim about jamming auditory pathways.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [35/505] bio_PIIS0092867425000467_images_figure_4.jpg
# 📋 Claim: Such diffusion accumulation of FITC in lamina propria already evident in nascent...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: FITC fluorescence in lamina propria increases by Day 3, aligning with the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [36/505] bio_PIIS0092867425000467_images_figure_5.jpg
# 📋 Claim: Between groups, transference of leptin MSH emerged as notably more efficient tha...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Leptin and α-MSH bars are taller than FITC, indicating higher basal compartment ratios.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [37/505] bio_PIIS0092867425000467_images_figure_5.jpg
# 📋 Claim: By 24 h mark, roughly 40% of leptin MSH discernible in basal compartment, nearly...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar height for Leptin at 24 hours is approximately 40%, matching the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [38/505] bio_PIIS0092867425000467_images_figure_5.jpg
# 📋 Claim: delivery efficiency of BDNF by Lp also comparable to of FITC, indicated by simil...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Similar basal compartment ratios for BDNF and FITC indicate comparable delivery efficiency.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [39/505] bio_PIIS0092867425000467_images_figure_6.jpg
# 📋 Claim: Over 8 week treatment, mice treated with leptinsecreting Lp exhibited reduced we...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Leptin-secreting Lp group shows lower body weight gain compared to PBS EV after 3 weeks.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [40/505] bio_PIIS0092867425000467_images_figure_6.jpg
# 📋 Claim: more, mice displayed reduced fat mass deposition, shown by significantly reduced...
# 🎯 Ground Truth: ['Panel F' 'Panel G' 'Panel H' 'Panel I']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Reduced fat mass in subcutaneous, peri-gonadal, peri-renal regions and lower hepatic TAG levels are visually supported by shorter bars and lower values compared to PBS group.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [41/505] bio_PIIS0092867425000467_images_figure_6.jpg
# 📋 Claim: Correspondingly, administration of engineered microbes prevented liver microstea...
# 🎯 Ground Truth: ['Panel J']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Liver microsteatosis is visibly reduced in mice treated with leptin, α-MSH, and BDNF compared to PBS and EV controls.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [42/505] bio_PIIS0092867425000467_images_figure_7.jpg
# 📋 Claim: Additionally, intranasal administration of engineered Lp led to significantly im...
# 🎯 Ground Truth: ['Panel E' 'Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Lower fasting glucose levels in r-Lep-LD and Lp-Lep-LD groups compared to PBS and r-Lep groups.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [43/505] bio_PIIS0092867425000479_images_figure_2.jpg
# 📋 Claim: found stimulation of CCK neurons rapidly reversibly suppressed food intake on or...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a significant drop in food intake upon laser stimulation, supporting rapid suppression of food intake.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [44/505] bio_PIIS0092867425000479_images_figure_3.jpg
# 📋 Claim: Consistent with hypothesis, also found integrated CCK neuron activity during mea...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a positive correlation between meal size and area under the curve (AUC), indicating increased CCK neuron activity with larger meals.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [45/505] bio_PIIS0092867425000479_images_figure_3.jpg
# 📋 Claim: due to intrinsic cellular network properties, integrated activity of neurons als...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a positive correlation between meal size and AUC, indicating reliable tracking.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [46/505] bio_PIIS0092867425000479_images_figure_4.jpg
# 📋 Claim: closer inspection, found meal size significantly increased, predicted by negativ...
# 🎯 Ground Truth: ['Panel H']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: Bar height indicates smaller average meal size, contradicting the claim of increased meal size.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [47/505] bio_PIIS0092867425000479_images_figure_5.jpg
# 📋 Claim: neurons not respond to sensory presentation of arbitrary, non - food object, dem...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a significant increase in response to the "Chow" object compared to the "Object," supporting the claim that neurons specifically respond to food.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [48/505] bio_PIIS0092867425000479_images_figure_4.jpg
# 📋 Claim: Using approach, found meal size significantly reduced compared with controls....
# 🎯 Ground Truth: ['Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar height for ChR2 shows significantly smaller average meal size than control.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [49/505] bio_PIIS0092867425000479_images_figure_5.jpg
# 📋 Claim: Importantly, presentation of same foil without food enclosed had impact on neuro...
# 🎯 Ground Truth: ['Panel D']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The bar graph shows a significant increase in neuronal activity for the "Covered chow" condition compared to "Cover only," supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [50/505] bio_PIIS0092867425000509_images_figure_1.jpg
# 📋 Claim: corresponded with less pro - inflammatory cytokine IL-1b IL-6 production, decrea...
# 🎯 Ground Truth: ['Panel R' 'Panel S' 'Panel T']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Panel R shows lower IL-1β and IL-6 levels in LAND-Vs-treated mice compared to PBS, supporting reduced inflammation.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [51/505] bio_PIIS0092867425000509_images_figure_1.jpg
# 📋 Claim: In lethal S. aureus pneumonia model, mice treated with single dose of LAND V dis...
# 🎯 Ground Truth: ['Panel U' 'Panel V']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Panel U shows increased survival rates for LAND-Vs-treated mice compared to PBS group.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [52/505] bio_PIIS0092867425000509_images_figure_1.jpg
# 📋 Claim: Notably, reducing inflammation, LAND V treatment not hinder bacterial clearance ...
# 🎯 Ground Truth: ['Panel W' 'Panel X']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: LAND-Vs treated group shows lower BALF CFU count compared to PBS group, supporting reduced bacterial load.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [53/505] bio_PIIS0092867425000509_images_figure_5.jpg
# 📋 Claim: Aged neutrophils manifested higher levels of ordered lipids compared with freshl...
# 🎯 Ground Truth: ['Panel K']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a higher GP value for aged neutrophils compared to fresh ones, indicating more ordered lipids.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [54/505] bio_PIIS0092867425000509_images_figure_5.jpg
# 📋 Claim: LAND V production dependent on actin cytoskeleton rearrangement, treatment with ...
# 🎯 Ground Truth: ['Panel V']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Jasplakinolide treatment reduces LAND-V count, supporting reduced actin cytoskeleton rearrangement.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [55/505] bio_PIIS0092867425000509_images_figure_7.jpg
# 📋 Claim: heightened response led to increased inflammation, with surge in CD45 cell neutr...
# 🎯 Ground Truth: ['Panel D' 'Panel E' 'Panel F' 'Panel H' 'Panel I']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Panels D, E, and F show increasing trends in CD45 cell recruitment, BALF neutrophil number, and total protein, respectively, indicating heightened inflammation and tissue damage.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [56/505] bio_PIIS0092867425000960_images_figure_6.jpg
# 📋 Claim: activation of STING, Golgi transit of mCherryTNF - delayed....
# 🎯 Ground Truth: ['Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a delayed peak in normalized fluorescence intensity for WT STING compared to inactive STING, supporting delayed Golgi transit.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [57/505] bio_PIIS0092867425000972_images_figure_1.jpg
# 📋 Claim: In mice devoid of T cells, mammary epithelial density during pregnancy reduced c...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Mammary epithelial density appears higher in TCRα+/+ mice than in TCRα-/- mice during pregnancy.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [58/505] bio_PIIS0092867425000972_images_figure_3.jpg
# 📋 Claim: By contrast, transferred into pregnant recipients, IELp migration differentiatio...
# 🎯 Ground Truth: ['Panel J']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Scatter plot shows higher CD8α+ IELp in nulliparous mice compared to pregnant recipients.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [59/505] bio_PIIS0092867425000972_images_figure_3.jpg
# 📋 Claim: In small intestine, differences observed between frequency of Ki67 + cells among...
# 🎯 Ground Truth: ['Panel L']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar graph shows higher Ki67+ cell frequency in small intestine from G10.5 recipient compared to nulliparous recipient.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [60/505] bio_PIIS009286742500100X_images_figure_6.jpg
# 📋 Claim: Importantly, found robust negative correlation between transcriptomic reversal o...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Scatter plot shows negative correlation between reversal fraction and normalized instability score.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [61/505] bio_PIIS009286742500145X_images_figure_2.jpg
# 📋 Claim: Active lysates enhanced vitC induced vitcylation, denatured lysates did not....
# 🎯 Ground Truth: ['Panel M']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Active lysates show higher vitC-induced vitcylation intensity compared to denatured lysates.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [62/505] bio_PIIS0092867425001552_images_figure_1.jpg
# 📋 Claim: Longicatena innocuum specifically utilized arbutin, esculin, helicin, salicin de...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Longicatena innocuum shows no growth in salidroside and amygdalin, aligning with the claim's absence of growth for these compounds.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [63/505] bio_PIIS0092867425001552_images_figure_2.jpg
# 📋 Claim: Similarly, find inability to utilize of glycosides species wide trait of B. vulg...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: B. vulgatus and B. dorei show growth curves for glycosides, indicating they can utilize these compounds.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [64/505] bio_PIIS0092867425001552_images_figure_5.jpg
# 📋 Claim: Using targeted LC MS approach, found across polyphenolic glycoside, B. uniformis...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The chromatograms show distinct peaks for aglycones after deglycosylation, supporting the claim of liberation of predicted aglycone products.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [65/505] bio_PIIS0092867425001552_images_figure_5.jpg
# 📋 Claim: For aryl glycoside, arbutin, salidroside, gastrodin, helicin salicin, B. uniform...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Arbutin, salidroside, gastrodin, helicin, salicin peaks align with their respective aglycone traces.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [66/505] bio_PIIS0092867425001552_images_figure_6.jpg
# 📋 Claim: parent polyphenolic glycosides phloridzin polydatin anti - microbial against C. ...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Polydatin shows significant enhancement against C. difficile in Panel A.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [67/505] bio_PIIS0092867425001552_images_figure_7.jpg
# 📋 Claim: aryl glycoside gastrodin not impact macrophage inflammatory cytokine production,...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Gastrodin's bars for TNF and IL-6 are similar to the control, indicating no significant impact.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [68/505] bio_PIIS0092867425001552_images_figure_7.jpg
# 📋 Claim: However, B.-uniformis liberated aglycone, naringenin repressed enhanced TNF prod...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Naringenin bars show higher TNF levels compared to glycoside, supporting repression of TNF production.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [69/505] bio_PIIS0092867425001552_images_figure_7.jpg
# 📋 Claim: Colonization of germ free mice with Bu WT Bu GHDDD followed by oral administrati...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Salicin administration leads to increased saligenin levels in feces, supporting Bu-dependent saligenin liberation.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [70/505] bio_PIIS0092867425001564_images_figure_4.jpg
# 📋 Claim: ERV derived peptide ATFLGSLTGK, similar to NDRG1 derived peptides, among most hi...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: ATFLGSLTGK is highlighted as one of the most upregulated HLA-bound peptides in the scatter plot.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [71/505] bio_PIIS0092867425001564_images_figure_5.jpg
# 📋 Claim: expected, increased chromatin accessibility of ERVs generally associated with in...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Scatter plot shows higher Log2(FC) for cancer compared to immune cells, indicating increased ERV expression in cancer.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [72/505] bio_PIIS0092867425001618_images_figure_2.jpg
# 📋 Claim: First, quantile quantile Q Q plots comparing p values for genetic variants assoc...
# 🎯 Ground Truth: ['Panel A' 'Panel B' 'Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Panels A and B show upward slopes indicating stronger genetic signals in European and African ancestries compared to expected.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [73/505] bio_PIIS0092867425001618_images_figure_4.jpg
# 📋 Claim: resulted in inferior septum perfused by right left....
# 🎯 Ground Truth: ['Panel H']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Inferior septum is perfused by right marginal artery, aligning with the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [74/505] bio_PIIS0092867425001928_images_figure_2.jpg
# 📋 Claim: Therefore, in contrast to current knowledge, neuronal soma in human, macaque, pi...
# 🎯 Ground Truth: ['Panel J']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The diagram shows a sequential arrangement of PNS microglia, SGCs, and neurons, supporting the claim's sequence.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [75/505] bio_PIIS0092867425001928_images_figure_2.jpg
# 📋 Claim: High resolution confocal z stack analysis further verified PNS microglia like ce...
# 🎯 Ground Truth: ['Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Confocal z stack images show direct contact between PNS microglia-like cells and neuronal soma.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [76/505] bio_PIIS0092867425001928_images_figure_4.jpg
# 📋 Claim: Macrophage progenitors most proliferative primarily enriched in yolk sac / embry...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Log normalized expression levels of macrophage progenitors are highest in early Carnegie stages.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [77/505] bio_PIIS0092867425001928_images_figure_5.jpg
# 📋 Claim: SGC envelope formed, percentage of PNS microglia like cells residing inside SGC ...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Microglia-like cells are shown inside the SGC envelope, increasing with age.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [78/505] bio_PIIS0092867425001928_images_figure_5.jpg
# 📋 Claim: During process, found neurons enwrapped by PNS microglia like cells first during...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Box plot shows larger neuronal soma size for enwrapped neurons compared to all neurons across species.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [79/505] bio_PIIS0092867425001928_images_figure_5.jpg
# 📋 Claim: more, SG neurons have smaller soma DRG neurons contained fewer PNS microglia lik...
# 🎯 Ground Truth: ['Panel H']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: SG neurons have smaller soma compared to DRG neurons, supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [80/505] bio_PIIS0092867425002594_images_figure_1.jpg
# 📋 Claim: Under conditions, loading less efficient still produced distinctive ladder....
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The ladder pattern in the gel confirms loading efficiency despite reduced efficiency.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [81/505] bio_PIIS0092867425002594_images_figure_1.jpg
# 📋 Claim: observed loading stimulated by P. thracensis Topo IV E. coli Topo, not by DNA gy...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The gel lanes show increased loading with P. thracensis Topo IV and E. coli Topo compared to DNA gyrase.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [82/505] bio_PIIS0092867425002594_images_figure_4.jpg
# 📋 Claim: Similar to P. thracensis complex, E. coli MukBEF6C efficiently produced SDS resi...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: E. coli MukBEF6C did not produce an SDS-resistant ladder like P. thracensis complex.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [83/505] bio_PIIS0092867425002703_images_figure_3.jpg
# 📋 Claim: effect confirmed by series of simulations in increasing numbers of PS lipids fli...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Scatter plot shows increasing tension with more PS lipids flipped, confirming the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [84/505] bio_PIIS0092867425002703_images_figure_2.jpg
# 📋 Claim: By directly quantifying amount of extracted PL, induced interleaflet PL abundanc...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a decreasing trend in intact vesicle scattering intensity with increasing cholesterol content, consistent with the claim's description of protection against vesicle destruction.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [85/505] bio_PIIS0092867425002703_images_figure_4.jpg
# 📋 Claim: comparison between Chol PL diffusion in leaflet revealed differences attributabl...
# 🎯 Ground Truth: ['Panel H']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar heights show faster cholesterol diffusion in the cytoplasmic leaflet compared to the exoplasmic leaflet.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [86/505] bio_PIIS0092867425002703_images_figure_4.jpg
# 📋 Claim: In contrast, large differences between Chol PL diffusion not observed in of leaf...
# 🎯 Ground Truth: ['Panel H']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar heights show similar cholesterol diffusion rates in Exo+ and Equal models.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [87/505] bio_PIIS0092867425002703_images_figure_5.jpg
# 📋 Claim: large lipid asymmetries suggest presence of stress in membrane, first calculated...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a significant lateral pressure difference between the two leaflets, indicating large lipid asymmetries.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [88/505] bio_PIIS0092867425002703_images_figure_5.jpg
# 📋 Claim: observed many partial transitions of water molecules entering exiting cytosolic ...
# 🎯 Ground Truth: ['Panel D']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar heights show higher flux from cytosolic leaflet compared to exoplasmic leaflet, supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [89/505] bio_PIIS0092867425002703_images_figure_5.jpg
# 📋 Claim: Ionophore treatment produced predicted scrambling, AnxV binding, also concomitan...
# 🎯 Ground Truth: ['Panel G']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Ionophore treatment causes SH4-GFP and AnxV to localize differently over time, supporting predicted scrambling and AnxV binding.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [90/505] bio_PIIS0092867425002703_images_figure_6.jpg
# 📋 Claim: reasoned reducing SM levels lower Chol 's affinity for outer leaflet, leading to...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The figure shows an increase in cholesterol's affinity for the outer leaflet after SMase treatment, supporting the claim of redistribution.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [91/505] bio_PIIS0092867425002703_images_figure_7.jpg
# 📋 Claim: Consistent with inference GRAMD1b transports excess cytosolic leaflet Chol from ...
# 🎯 Ground Truth: ['Panel F']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Cytosolic Chol packing increased in cells loaded with PL-αCD, consistent with GRAMD1b's role in transporting excess Chol.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [92/505] bio_PIIS0092867425002715_images_figure_1.jpg
# 📋 Claim: clones within library exhibited progressive enrichment, others showed gradual de...
# 🎯 Ground Truth: ['Panel C']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Clones show increasing enrichment over rounds, supporting selective enrichment effect.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [93/505] bio_PIIS0092867425002715_images_figure_2.jpg
# 📋 Claim: In summary, utilizing Sort seq, successfully performed promoter library screenin...
# 🎯 Ground Truth: ['Panel A']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: NON_SUPPORT
# Reason: The panel does not contain relevant information about promoter library screening or heat shock stimulation.<|im_end|>
# ✅ Predicted: NON_SUPPORT
#
# ============================================================
# 🔍 [94/505] bio_PIIS0092867425002715_images_figure_2.jpg
# 📋 Claim: added NF kB responsive elements into promoter region to utilize NF kB signaling ...
# 🎯 Ground Truth: ['Panel D']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The scatter plot shows an increase in CAR+ percentage over time in monoculture, supporting the claim's assertion of increased sustainability.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [95/505] bio_PIIS0092867425002715_images_figure_2.jpg
# 📋 Claim: then added NFAT responsive elements into promoter region containing NF kB elemen...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The scatter plot shows increased CAR+ percentage over time after adding NFAT elements, supporting reduced downregulation.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [96/505] bio_PIIS0092867425002715_images_figure_3.jpg
# 📋 Claim: By contrast, EchoBack CAR T cells with two more additional FUS treatments signif...
# 🎯 Ground Truth: ['Panel H' 'Panel I']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: EchoBack-CAR T (FUS) shows significantly smaller tumor sizes compared to non-FUS treated groups.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [97/505] bio_PIIS0092867425002715_images_figure_5.jpg
# 📋 Claim: Unsupervised clustering analysis identified 8 unique clusters / subpopulations o...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The UMAP plot clearly shows 8 distinct clusters of CAR T cells, supporting the claim.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [98/505] bio_PIIS0092867425002715_images_figure_5.jpg
# 📋 Claim: Through signaling pathway analysis, found functional IL signaling e.g., IL-8, IL...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Enriched signaling pathways in EchoBack-CAR T cells are visually represented by higher bar heights for IL-8, IL-7, IL-2, IL-6, IL-1, mTOR, JAK/STAT, and GM-CSF signaling compared to Standard CAR T cells.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [99/505] bio_PIIS0092867425002715_images_figure_6.jpg
# 📋 Claim: Remarkably, PSMACAR expression on surface remain at high level for up to 5 days ...
# 🎯 Ground Truth: ['Panel B']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The graph shows a steady decline in PSMACAR expression over time, contradicting the claim of high-level expression lasting 5 days.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [100/505] bio_PIIS0092867425002715_images_figure_5.jpg
# 📋 Claim: also found difference in killing capability of pre - activated EchoBack CAR T ce...
# 🎯 Ground Truth: ['Panel L']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: Bar graph shows higher killing efficiency for EchoBack-CAR T cells post-chronic antigen stimulation compared to before.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [101/505] bio_PIIS0092867425002727_images_figure_1.jpg
# 📋 Claim: also observed loss of binding of VLDLR LBD Fc duck MXRA8 Fc to E1 Y85A E1 F87A, ...
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The bar heights for Y85A and F87A show reduced binding affinity compared to wild-type, supporting the claim of loss of binding.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [102/505] bio_PIIS0092867425002727_images_figure_4.jpg
# 📋 Claim: WT RRV VLPs not bind VLDLR LBD Fc, RRV DKTA VLPs did....
# 🎯 Ground Truth: ['Panel E']
# 🎯 Associated verdict: SUPPORT
# image_len: 1369, text_len: 15
# Verdict: SUPPORT
# Reason: The BLI signal for WT RRV VLPs is flat, while RRV DKTA VLPs show an increasing trend.<|im_end|>
# ✅ Predicted: SUPPORT
#
# ============================================================
# 🔍 [103/505] bio_PIIS0092867425002727_images_figure_6.jpg
# ...
#
# ============================================================
# 🔍 [467/505] jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
# 📋 Claim: increased number of nucleation sites available on surface of spherical seeds als...
# 🎯 Ground Truth: ['No panel markings']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [467]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
#
# ============================================================
# 🔍 [468/505] jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
# 📋 Claim: Specifically, Pt atoms preferred to nucleate grow from low coordination corners ...
# 🎯 Ground Truth: ['No panel markings']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [468]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
#
# ============================================================
# 🔍 [469/505] jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
# 📋 Claim: octahedral seed provided six corners for nucleation left route, cubic seed offer...
# 🎯 Ground Truth: ['No panel markings']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [469]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
#
# ============================================================
# 🔍 [470/505] jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
# 📋 Claim: In contrast, higher abundance of high index facets on surface of spherical seed ...
# 🎯 Ground Truth: ['No panel markings']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [470]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c03700_images_figure_5.jpg
#
# ============================================================
# 🔍 [471/505] jacs_data_10.1021_jacs.5c08267_images_figure_1.jpg
# 📋 Claim: highly ordered two dimensional 2D hexagonal channels clearly observed from high ...
# 🎯 Ground Truth: ['Figure 1D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [471]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_1.jpg
#
# ============================================================
# 🔍 [472/505] jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
# 📋 Claim: powder X - ray diffraction XRD pattern shows three diffraction peaks at 4.3, 8.5...
# 🎯 Ground Truth: ['Figure 2B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [472]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
#
# ============================================================
# 🔍 [473/505] jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
# 📋 Claim: SICPE membrane without COF316 turns from colorless to yellow after introducing C...
# 🎯 Ground Truth: ['Figure 2D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [473]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
#
# ============================================================
# 🔍 [474/505] jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
# 📋 Claim: more, due to ion dipole interaction between Li+ −C≡N, X - ray photoelectron spec...
# 🎯 Ground Truth: ['Figure 2G']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [474]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
#
# ============================================================
# 🔍 [475/505] jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
# 📋 Claim: more, due to ion dipole interaction between Li+ −C≡N, X - ray photoelectron spec...
# 🎯 Ground Truth: ['Figure 2G']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [475]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
#
# ============================================================
# 🔍 [476/505] jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
# 📋 Claim: PLF@COF316 bears higher mechanical strength stretchability than PLF, attributed ...
# 🎯 Ground Truth: ['Figure 2I']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [476]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_2.jpg
#
# ============================================================
# 🔍 [477/505] jacs_data_10.1021_jacs.5c08267_images_figure_3.jpg
# 📋 Claim: PLF chains homogeneously distributed in box....
# 🎯 Ground Truth: ['Figure 3D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [477]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_3.jpg
#
# ============================================================
# 🔍 [478/505] jacs_data_10.1021_jacs.5c08267_images_figure_4.jpg
# 📋 Claim: activation energy Ea of PLF@COF316 calculated to 0.15 eV, much lower than of PLF...
# 🎯 Ground Truth: ['Figure 4E']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [478]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_4.jpg
#
# ============================================================
# 🔍 [479/505] jacs_data_10.1021_jacs.5c08267_images_figure_6.jpg
# 📋 Claim: Two distinct regions detected in NCM811 with PLF electrolyte....
# 🎯 Ground Truth: ['Figure 6A']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [479]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_6.jpg
#
# ============================================================
# 🔍 [480/505] jacs_data_10.1021_jacs.5c08267_images_figure_6.jpg
# 📋 Claim: more, CEI generated from PLF@COF316 displays higher intensity of LiF than of PLF...
# 🎯 Ground Truth: ['Figure 6C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [480]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08267_images_figure_6.jpg
#
# ============================================================
# 🔍 [481/505] jacs_data_10.1021_jacs.5c05637_images_figure_2.jpg
# 📋 Claim: visualization for 3b meta carborane clearly shows more negative potential corres...
# 🎯 Ground Truth: ['Figure 2D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [481]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c05637_images_figure_2.jpg
#
# ============================================================
# 🔍 [482/505] jacs_data_10.1021_jacs.5c08663_images_figure_4.jpg
# 📋 Claim: Synthetic conjugation ready LPS fragments of P. gingivalis immobilized on NHS ac...
# 🎯 Ground Truth: ['Figure 4A' 'Figure 4B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [482]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08663_images_figure_4.jpg
#
# ============================================================
# 🔍 [483/505] jacs_data_10.1021_jacs.5c08663_images_figure_4.jpg
# 📋 Claim: Human IgG antibodies in saliva bind with highest MFI to LPS-2 tetrasaccharidE....
# 🎯 Ground Truth: ['Figure 4D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [483]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08663_images_figure_4.jpg
#
# ============================================================
# 🔍 [484/505] jacs_data_10.1021_jacs.5c08663_images_figure_5.jpg
# 📋 Claim: IgM antibodies remained at low level....
# 🎯 Ground Truth: ['Figure 5B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [484]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08663_images_figure_5.jpg
#
# ============================================================
# 🔍 [485/505] jacs_data_10.1021_jacs.5c08663_images_figure_5.jpg
# 📋 Claim: IgG antibody levels started to increase at day 28 after initial immunization sta...
# 🎯 Ground Truth: ['Figure 5C' 'Figure 5D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [485]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c08663_images_figure_5.jpg
#
# ============================================================
# 🔍 [486/505] jacs_data_10.1021_jacs.5c09199_images_figure_5.jpg
# 📋 Claim: For catalyst types, volcano model peaks decrease as pH decreases, indicating hig...
# 🎯 Ground Truth: ['Figure 5A' 'Figure 5B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [486]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c09199_images_figure_5.jpg
#
# ============================================================
# 🔍 [487/505] jacs_data_10.1021_jacs.4c15836_images_figure_1.jpg
# 📋 Claim: Machine learning results SAXS experiments consistently show Drp1 has intrinsic a...
# 🎯 Ground Truth: ['Figure 1A']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [487]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.4c15836_images_figure_1.jpg
#
# ============================================================
# 🔍 [488/505] jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
# 📋 Claim: Based on results at two P / L ratios 1/4000 1/2000, find fission neck size chang...
# 🎯 Ground Truth: ['Figure 3C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [488]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
#
# ============================================================
# 🔍 [489/505] jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
# 📋 Claim: suggests Drp1 has greater membrane curvature generating capacity after GTP(nh re...
# 🎯 Ground Truth: ['Figure 3C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [489]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
#
# ============================================================
# 🔍 [490/505] jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
# 📋 Claim: suggests Drp1 has greater membrane curvature generating capacity after GTP(nh re...
# 🎯 Ground Truth: ['Figure 3C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [490]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
#
# ============================================================
# 🔍 [491/505] jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
# 📋 Claim: same trend of gradual radii decrease from 8.13 to 5.30 nm, 34.8% of decreasing a...
# 🎯 Ground Truth: ['Figure 3D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [491]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.4c15836_images_figure_3.jpg
#
# ============================================================
# 🔍 [492/505] jacs_data_10.1021_jacs.5c02947_images_figure_1.jpg
# 📋 Claim: droplets in sample have broad distribution of diameters....
# 🎯 Ground Truth: ['Figure 1C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [492]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_1.jpg
#
# ============================================================
# 🔍 [493/505] jacs_data_10.1021_jacs.5c02947_images_figure_1.jpg
# 📋 Claim: have remarkably narrow distribution of refractive indexes....
# 🎯 Ground Truth: ['Figure 1C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [493]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_1.jpg
#
# ============================================================
# 🔍 [494/505] jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
# 📋 Claim: microscopy reveals presence of condensates at concentration, differences in cond...
# 🎯 Ground Truth: ['Figure 2A']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [494]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
#
# ============================================================
# 🔍 [495/505] jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
# 📋 Claim: concentration of PopZ in dense phase increases with increasing concentration of ...
# 🎯 Ground Truth: ['Figure 2A']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [495]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
#
# ============================================================
# 🔍 [496/505] jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
# 📋 Claim: four types of cations induce liquid liquid phase separation produce spherical co...
# 🎯 Ground Truth: ['Figure 2B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [496]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
#
# ============================================================
# 🔍 [497/505] jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
# 📋 Claim: Droplets produced in roughly same numbers with four types of cations protein con...
# 🎯 Ground Truth: ['Figure 2B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [497]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_2.jpg
#
# ============================================================
# 🔍 [498/505] jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
# 📋 Claim: Instead, scaled distribution functions broaden with time, only appears to reach ...
# 🎯 Ground Truth: ['Figure 3D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [498]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
#
# ============================================================
# 🔍 [499/505] jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
# 📋 Claim: number density of detectable condensates increases for first half hour condensat...
# 🎯 Ground Truth: ['Figure 3B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [499]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
#
# ============================================================
# 🔍 [500/505] jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
# 📋 Claim: number density declines after hour, suggests coarsening outstrips nucleation rat...
# 🎯 Ground Truth: ['Figure 3B']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [500]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
#
# ============================================================
# 🔍 [501/505] jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
# 📋 Claim: more, logarithmic dependence of mean droplet size consistent with fractal dimens...
# 🎯 Ground Truth: ['Figure 3D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [501]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_3.jpg
#
# ============================================================
# 🔍 [502/505] jacs_data_10.1021_jacs.5c02947_images_figure_4.jpg
# 📋 Claim: PopZ condensates imaged via DIC microscopy appeared smaller less distinct at hig...
# 🎯 Ground Truth: ['Figure 4A']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [502]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_4.jpg
#
# ============================================================
# 🔍 [503/505] jacs_data_10.1021_jacs.5c02947_images_figure_4.jpg
# 📋 Claim: observed distribution shift toward small sized condensates with high refractive ...
# 🎯 Ground Truth: ['Figure 4C']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [503]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_4.jpg
#
# ============================================================
# 🔍 [504/505] jacs_data_10.1021_jacs.5c02947_images_figure_5.jpg
# 📋 Claim: By employing oblique illumination to further minimize perturbations, observed in...
# 🎯 Ground Truth: ['Figure 5A']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [504]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_5.jpg
#
# ============================================================
# 🔍 [505/505] jacs_data_10.1021_jacs.5c02947_images_figure_5.jpg
# 📋 Claim: simulations revealed distinct interaction profiles....
# 🎯 Ground Truth: ['Figure 5D']
# 🎯 Associated verdict: SUPPORT
#
# ⚠️ Skipping [505]: Image not found at /content/drive/MyDrive/VLM/paper_figures/jacs_data_10.1021_jacs.5c02947_images_figure_5.jpg
# Accuracy: 87.81094527363184%
